# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import renderers.cairo_path_renderer as cr
import matplotlib.pyplot as plt

# %%
renderer = cr.CairoPathRenderer()
canvas = renderer.draw([[0.5, 0.5], [0.8, 0.5], [0.8, 0.8], [0.5, 0.8]], thickness=4)
plt.imshow(canvas)
