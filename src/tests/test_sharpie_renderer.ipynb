# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import renderers.sharpie_renderer as sr
import matplotlib.pyplot as plt

# %%
renderer = sr.SharpieRenderer()
canvas = renderer.draw([[0.5, 0.5], [0.8, 0.5], [0.8, 0.8], [0.5, 0.8]])
plt.imshow(canvas)
